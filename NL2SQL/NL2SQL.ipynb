# %%
! pip install sqlite3
# Out:
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3

# %%
import sqlite3
import pandas as pd

# Connect to SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect('my_database.db')

# Load data from CSV file into a DataFrame
df = pd.read_csv('dataset.csv')

# Write the data from pandas DataFrame to SQLite table
df.to_sql('data', conn, if_exists='replace', index=False)

# Verify by querying the data back
#pd.read_sql('SELECT * FROM ', conn)
# Out:
# 1110

# %%
df
# Out:
#       img_id       Sample Image                                          Name  \
# 0       21.0  to complete   NaN     480 Galerie du Travail. Section Japonaise
# 1       52.0  to complete   NaN                 363 Elephant et son Palanquin
# 2       59.0  to complete   NaN                              [L&L] Untitled 3
# 3       91.0  to complete   NaN                 474 Le Cavalier Marocain (BM)
# 4       96.0  to complete   NaN                 [L&L] Section Wurtembergeoise
# ...      ...          ...   ...                                           ...
# 1105  1096.0          NaN   NaN   N487 - Galerie du travail, Section Ottomane
# 1106  1097.0          NaN   NaN  N489 - Galerie du Travail, Section japonaise
# 1107  1103.0          NaN   NaN  N570 - Galerie du Travail, Section française
# 1108  1104.0          NaN   NaN             N575 - Vue dans le Jardin central
# 1109  1105.0          NaN   NaN        N590 - Vue panoramique du parc Ottoman
#
#      Image Name  expo_id         Country Group Class Class Description  ...  \
# 0           NaN    480.0           Japan   NaN   NaN               NaN  ...
# 1           NaN    363.0           Japan   NaN   NaN               NaN  ...
# 2           NaN      NaN             NaN   NaN   NaN               NaN  ...
# 3           NaN    474.0         Morocco   NaN   NaN               NaN  ...
# 4           NaN      NaN     Württemberg   NaN   NaN               NaN  ...
# ...         ...      ...             ...   ...   ...               ...  ...
# 1105        NaN    487.0  Ottoman Empire   NaN   NaN               NaN  ...
# 1106        NaN    489.0           Japan   NaN   NaN               NaN  ...
# 1107        NaN    570.0          France   NaN   NaN               NaN  ...
# 1108        NaN    575.0  Jardin Central   NaN   NaN               NaN  ...
# 1109        NaN    590.0  Ottoman Empire   NaN   NaN               NaN  ...
#
#       Excerpt Image  Excerpted Source(s) Source File(s) Associated Image(s)  \
# 0                NaN                 NaN            NaN                 NaN
# 1                NaN                 NaN            NaN                 NaN
# 2                NaN                 NaN            NaN                 NaN
# 3                NaN                 NaN            NaN                 NaN
# 4                NaN                 NaN            NaN                 NaN
# ...              ...                 ...            ...                 ...
# 1105             NaN                 NaN            NaN                 NaN
# 1106             NaN                 NaN            NaN                 NaN
# 1107             NaN                 NaN            NaN                 NaN
# 1108             NaN                 NaN            NaN                 NaN
# 1109             NaN                 NaN            NaN                 NaN
#
#      Links Comments                          Medium       Author  \
# 0      NaN      NaN             Architecture,Animal  Leon & Levy
# 1      NaN      NaN             Architecture,Animal  Leon & Levy
# 2      NaN      NaN                             NaN  Leon & Levy
# 3      NaN      NaN                             NaN  Leon & Levy
# 4      NaN      NaN                       Birdcage?  Leon & Levy
# ...    ...      ...                             ...          ...
# 1105   NaN      NaN          Architecture, Industry  Leon & Levy
# 1106   NaN      NaN  Architecture, Industry, Animal  Leon & Levy
# 1107   NaN      NaN          Architecture, Industry  Leon & Levy
# 1108   NaN      NaN                  Jardin Central  Leon & Levy
# 1109   NaN      NaN   Architecture, Landscape, Expo  Leon & Levy
#
#      Approx Orig Resolution                       Collection
# 0                      7100                  François Brunet
# 1                      2000               Patrick Montgomery
# 2                      4500                        Brian May
# 3                      4500                        Brian May
# 4                      1050    Archives Nationales de France
# ...                     ...                              ...
# 1105              8000x4045  Bibliotheque National de France
# 1106              8000x4045  Bibliotheque National de France
# 1107              8000x4045  Bibliotheque National de France
# 1108              8000x4053  Bibliotheque National de France
# 1109              8000x4001  Bibliotheque National de France
#
# [1110 rows x 43 columns]

# %%
# Create a cursor object
cursor = conn.cursor()

# Define the SQL query
query = '''
SELECT img_id
FROM data
WHERE country = 'Japan'
'''

# Execute the SQL query
cursor.execute(query)

# Fetch all rows of the query result
results = cursor.fetchall()

# Check if any results have been returned
if results:
    # Print results
    print("image_id", sep="\t")
    for row in results:
        print(row[0], sep="\t")
else:
    print("No Japan images found.")

# Close the cursor and connection to free up resources
cursor.close()
conn.close()
# Out:
# image_id
# 21.0
# 52.0
# 1091.0
# 1099.0
# 56.0
# 1097.0
